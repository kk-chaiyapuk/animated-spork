# %% [markdown]
# # Adjust Rating and Genre

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.stats.outliers_influence as sm_vif
from math import exp

# %%
df_movies = pd.read_csv('df_movies.csv')

# %% [markdown]
# ## Adjust Genre

# %%
df_movies.groupby('genre_adj').size()
# Out:
# genre_adj
# Action       1210
# Adventure     259
# Comedy       1263
# Drama         665
# Others       1009
# dtype: int64

# %% [markdown]
# ## Adjust Rating

# %%
df_movies.groupby('rating_adj').size()
# Out:
# rating_adj
# G and PG                863
# PG-13                  1587
# R, NC-17 and others    1956
# dtype: int64

# %% [markdown]
# # Profitability Models

# %% [markdown]
# ### base without Gender

# %%
# Add dummy variable for budget that is above the median
df_movies["over_median_budget_adj_flag"] = df_movies["budget_adj"] > df_movies["budget_adj"].median()
# df_movies["over_median_budget_adj_flag"] = df_movies["budget_adj"] > df_movies["budget_adj"].quantile(0.75)


# A model without Gender for comparision
model_profit_base = sm.OLS.from_formula('profitability_ln ~ over_median_budget_adj_flag + np.log(budget_adj) + year + score + rating_adj + genre_adj', df_movies)
print(model_profit_base.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       profitability_ln   R-squared:                       0.241
# Model:                            OLS   Adj. R-squared:                  0.239
# Method:                 Least Squares   F-statistic:                     122.9
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):          2.74e-223
# Time:                        23:16:04   Log-Likelihood:                -4968.8
# No. Observations:                3891   AIC:                             9960.
# Df Residuals:                    3880   BIC:                         1.003e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.3176      0.132      2.398      0.017       0.058       0.577
# over_median_budget_adj_flag[T.True]     0.2859      0.043      6.621      0.000       0.201       0.371
# rating_adj[T.PG-13]                    -0.1592      0.042     -3.798      0.000      -0.241      -0.077
# rating_adj[T.R, NC-17 and others]      -0.4557      0.041    -11.027      0.000      -0.537      -0.375
# genre_adj[T.Adventure]                 -0.1923      0.065     -2.950      0.003      -0.320      -0.065
# genre_adj[T.Comedy]                    -0.1526      0.040     -3.833      0.000      -0.231      -0.075
# genre_adj[T.Drama]                     -0.3296      0.047     -6.961      0.000      -0.422      -0.237
# genre_adj[T.Others]                    -0.1154      0.041     -2.791      0.005      -0.196      -0.034
# np.log(budget_adj)                     -0.5102      0.023    -21.983      0.000      -0.556      -0.465
# year                                    0.0160      0.001     11.197      0.000       0.013       0.019
# score                                   0.3451      0.015     22.303      0.000       0.315       0.375
# ==============================================================================
# Omnibus:                       22.188   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.246
# Skew:                           0.088   Prob(JB):                     7.35e-07
# Kurtosis:                       3.379   Cond. No.                         265.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Gender as a constant

# %%
# Add Gender
model_profit_gen_constant = sm.OLS.from_formula('profitability_ln ~ gender + np.log(budget_adj) + year + score + rating_adj + genre_adj', df_movies)
print(model_profit_gen_constant.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       profitability_ln   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     118.7
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):          1.96e-216
# Time:                        23:16:04   Log-Likelihood:                -4984.8
# No. Observations:                3891   AIC:                             9992.
# Df Residuals:                    3880   BIC:                         1.006e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1578      0.130      1.214      0.225      -0.097       0.413
# gender[T.male]                       -0.1230      0.036     -3.439      0.001      -0.193      -0.053
# rating_adj[T.PG-13]                  -0.1720      0.042     -4.082      0.000      -0.255      -0.089
# rating_adj[T.R, NC-17 and others]    -0.4600      0.041    -11.085      0.000      -0.541      -0.379
# genre_adj[T.Adventure]               -0.2002      0.066     -3.056      0.002      -0.329      -0.072
# genre_adj[T.Comedy]                  -0.1897      0.040     -4.723      0.000      -0.268      -0.111
# genre_adj[T.Drama]                   -0.3588      0.048     -7.474      0.000      -0.453      -0.265
# genre_adj[T.Others]                  -0.1346      0.042     -3.228      0.001      -0.216      -0.053
# np.log(budget_adj)                   -0.3946      0.016    -24.178      0.000      -0.427      -0.363
# year                                  0.0157      0.001     10.811      0.000       0.013       0.019
# score                                 0.3462      0.016     22.212      0.000       0.316       0.377
# ==============================================================================
# Omnibus:                       54.586   Durbin-Watson:                   1.678
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.030
# Skew:                           0.146   Prob(JB):                     1.54e-18
# Kurtosis:                       3.648   Cond. No.                         259.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Gender with budget_adj

# %%
# Add Gender * budget_adj
model_profit_gen_budget = sm.OLS.from_formula('profitability_ln ~ gender*over_median_budget_adj_flag + np.log(budget_adj) + year + score + rating_adj + genre_adj', df_movies)
print(model_profit_gen_budget.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       profitability_ln   R-squared:                       0.243
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     103.9
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):          3.27e-224
# Time:                        23:16:05   Log-Likelihood:                -4961.8
# No. Observations:                3891   AIC:                             9950.
# Df Residuals:                    3878   BIC:                         1.003e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.4019      0.136      2.948      0.003       0.135       0.669
# gender[T.male]                                        -0.1251      0.046     -2.749      0.006      -0.214      -0.036
# over_median_budget_adj_flag[T.True]                    0.3079      0.071      4.338      0.000       0.169       0.447
# rating_adj[T.PG-13]                                   -0.1675      0.042     -3.996      0.000      -0.250      -0.085
# rating_adj[T.R, NC-17 and others]                     -0.4582      0.041    -11.090      0.000      -0.539      -0.377
# genre_adj[T.Adventure]                                -0.2018      0.065     -3.095      0.002      -0.330      -0.074
# genre_adj[T.Comedy]                                   -0.1705      0.040     -4.258      0.000      -0.249      -0.092
# genre_adj[T.Drama]                                    -0.3544      0.048     -7.423      0.000      -0.448      -0.261
# genre_adj[T.Others]                                   -0.1305      0.041     -3.145      0.002      -0.212      -0.049
# gender[T.male]:over_median_budget_adj_flag[T.True]    -0.0193      0.071     -0.273      0.785      -0.158       0.119
# np.log(budget_adj)                                    -0.5069      0.023    -21.858      0.000      -0.552      -0.461
# year                                                   0.0153      0.001     10.606      0.000       0.012       0.018
# score                                                  0.3503      0.016     22.580      0.000       0.320       0.381
# ==============================================================================
# Omnibus:                       20.783   Durbin-Watson:                   1.678
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.810
# Skew:                           0.091   Prob(JB):                     2.49e-06
# Kurtosis:                       3.355   Cond. No.                         274.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Gender with year

# %%
# Add Gender * year
model_profit_gen_year = sm.OLS.from_formula('profitability_ln ~ gender*year + np.log(budget_adj) + score + rating_adj + genre_adj', df_movies)
print(model_profit_gen_year.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       profitability_ln   R-squared:                       0.235
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     108.2
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):          6.93e-216
# Time:                        23:16:05   Log-Likelihood:                -4983.6
# No. Observations:                3891   AIC:                             9991.
# Df Residuals:                    3879   BIC:                         1.007e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0297      0.155      0.192      0.848      -0.274       0.333
# gender[T.male]                        0.0222      0.102      0.219      0.827      -0.177       0.222
# rating_adj[T.PG-13]                  -0.1706      0.042     -4.050      0.000      -0.253      -0.088
# rating_adj[T.R, NC-17 and others]    -0.4595      0.041    -11.076      0.000      -0.541      -0.378
# genre_adj[T.Adventure]               -0.2015      0.065     -3.076      0.002      -0.330      -0.073
# genre_adj[T.Comedy]                  -0.1864      0.040     -4.636      0.000      -0.265      -0.108
# genre_adj[T.Drama]                   -0.3564      0.048     -7.422      0.000      -0.451      -0.262
# genre_adj[T.Others]                  -0.1316      0.042     -3.152      0.002      -0.213      -0.050
# year                                  0.0202      0.003      6.080      0.000       0.014       0.027
# gender[T.male]:year                  -0.0056      0.004     -1.524      0.128      -0.013       0.002
# np.log(budget_adj)                   -0.3928      0.016    -24.009      0.000      -0.425      -0.361
# score                                 0.3458      0.016     22.190      0.000       0.315       0.376
# ==============================================================================
# Omnibus:                       55.342   Durbin-Watson:                   1.679
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.947
# Skew:                           0.145   Prob(JB):                     5.90e-19
# Kurtosis:                       3.658   Cond. No.                         415.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Gender with both budget_adj and year

# %%
# Add Gender * both budget_adj & year
model_profit_gen_constant = sm.OLS.from_formula('profitability_ln ~ gender*over_median_budget_adj_flag + gender*year + np.log(budget_adj) + score + rating_adj + genre_adj', df_movies)
print(model_profit_gen_constant.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       profitability_ln   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     96.09
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):          1.34e-223
# Time:                        23:16:05   Log-Likelihood:                -4960.9
# No. Observations:                3891   AIC:                             9950.
# Df Residuals:                    3877   BIC:                         1.004e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              0.2878      0.160      1.802      0.072      -0.025       0.601
# gender[T.male]                                         0.0027      0.104      0.026      0.979      -0.201       0.206
# over_median_budget_adj_flag[T.True]                    0.3023      0.071      4.252      0.000       0.163       0.442
# rating_adj[T.PG-13]                                   -0.1662      0.042     -3.966      0.000      -0.248      -0.084
# rating_adj[T.R, NC-17 and others]                     -0.4577      0.041    -11.077      0.000      -0.539      -0.377
# genre_adj[T.Adventure]                                -0.2027      0.065     -3.111      0.002      -0.331      -0.075
# genre_adj[T.Comedy]                                   -0.1676      0.040     -4.181      0.000      -0.246      -0.089
# genre_adj[T.Drama]                                    -0.3523      0.048     -7.376      0.000      -0.446      -0.259
# genre_adj[T.Others]                                   -0.1277      0.042     -3.076      0.002      -0.209      -0.046
# gender[T.male]:over_median_budget_adj_flag[T.True]    -0.0139      0.071     -0.196      0.844      -0.153       0.125
# year                                                   0.0194      0.003      5.851      0.000       0.013       0.026
# gender[T.male]:year                                   -0.0050      0.004     -1.370      0.171      -0.012       0.002
# np.log(budget_adj)                                    -0.5048      0.023    -21.721      0.000      -0.550      -0.459
# score                                                  0.3499      0.016     22.555      0.000       0.320       0.380
# ==============================================================================
# Omnibus:                       21.190   Durbin-Watson:                   1.679
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.538
# Skew:                           0.090   Prob(JB):                     1.73e-06
# Kurtosis:                       3.363   Cond. No.                         430.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Revenue Models

# %%
model_base_gross = sm.OLS.from_formula('np.log(gross_adj) ~ gender', df_movies)
print(model_base_gross.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(gross_adj)   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     13.30
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):           0.000269
# Time:                        23:16:05   Log-Likelihood:                -6969.6
# No. Observations:                4406   AIC:                         1.394e+04
# Df Residuals:                    4404   BIC:                         1.396e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          4.2383      0.038    110.678      0.000       4.163       4.313
# gender[T.male]     0.1576      0.043      3.647      0.000       0.073       0.242
# ==============================================================================
# Omnibus:                      223.758   Durbin-Watson:                   1.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              140.028
# Skew:                           0.307   Prob(JB):                     3.92e-31
# Kurtosis:                       2.379   Cond. No.                         4.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Base without Gender

# %%
# This will be our base model before adding Gender
model_base_gross = sm.OLS.from_formula('np.log(gross_adj) ~ np.log(budget_adj) + year + score + rating_adj + genre_adj', df_movies)
print(model_base_gross.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(gross_adj)   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     340.2
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):               0.00
# Time:                        23:16:05   Log-Likelihood:                -4990.7
# No. Observations:                3891   AIC:                         1.000e+04
# Df Residuals:                    3881   BIC:                         1.006e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0793      0.128      0.619      0.536      -0.172       0.331
# rating_adj[T.PG-13]                  -0.1644      0.042     -3.902      0.000      -0.247      -0.082
# rating_adj[T.R, NC-17 and others]    -0.4581      0.042    -11.025      0.000      -0.540      -0.377
# genre_adj[T.Adventure]               -0.1921      0.066     -2.930      0.003      -0.321      -0.064
# genre_adj[T.Comedy]                  -0.1729      0.040     -4.331      0.000      -0.251      -0.095
# genre_adj[T.Drama]                   -0.3357      0.048     -7.053      0.000      -0.429      -0.242
# genre_adj[T.Others]                  -0.1207      0.042     -2.903      0.004      -0.202      -0.039
# np.log(budget_adj)                    0.5999      0.016     36.879      0.000       0.568       0.632
# year                                  0.0163      0.001     11.362      0.000       0.014       0.019
# score                                 0.3415      0.016     21.965      0.000       0.311       0.372
# ==============================================================================
# Omnibus:                       56.064   Durbin-Watson:                   1.675
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.144
# Skew:                           0.142   Prob(JB):                     1.97e-19
# Kurtosis:                       3.671   Cond. No.                         255.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Add gender into the base model

# %%
# Add gender into the base model
model_1_gross = sm.OLS.from_formula('np.log(gross_adj) ~ gender + np.log(budget_adj) + year + score + rating_adj + genre_adj', df_movies)
print(model_1_gross.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(gross_adj)   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     308.2
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):               0.00
# Time:                        23:16:05   Log-Likelihood:                -4984.8
# No. Observations:                3891   AIC:                             9992.
# Df Residuals:                    3880   BIC:                         1.006e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1578      0.130      1.214      0.225      -0.097       0.413
# gender[T.male]                       -0.1230      0.036     -3.439      0.001      -0.193      -0.053
# rating_adj[T.PG-13]                  -0.1720      0.042     -4.082      0.000      -0.255      -0.089
# rating_adj[T.R, NC-17 and others]    -0.4600      0.041    -11.085      0.000      -0.541      -0.379
# genre_adj[T.Adventure]               -0.2002      0.066     -3.056      0.002      -0.329      -0.072
# genre_adj[T.Comedy]                  -0.1897      0.040     -4.723      0.000      -0.268      -0.111
# genre_adj[T.Drama]                   -0.3588      0.048     -7.474      0.000      -0.453      -0.265
# genre_adj[T.Others]                  -0.1346      0.042     -3.228      0.001      -0.216      -0.053
# np.log(budget_adj)                    0.6054      0.016     37.090      0.000       0.573       0.637
# year                                  0.0157      0.001     10.811      0.000       0.013       0.019
# score                                 0.3462      0.016     22.212      0.000       0.316       0.377
# ==============================================================================
# Omnibus:                       54.586   Durbin-Watson:                   1.678
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.030
# Skew:                           0.146   Prob(JB):                     1.54e-18
# Kurtosis:                       3.648   Cond. No.                         259.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Add Gender *np.log(budget_adj)

# %%
# Add Gender *np.log(budget_adj)
model_2_gross = sm.OLS.from_formula('np.log(gross_adj) ~ gender*np.log(budget_adj) + year + np.log(budget_adj) + year + score + rating_adj + genre_adj', df_movies)
model_2_gross_fit = model_2_gross.fit()
print(model_2_gross_fit.summary())

male_ln_budget_adj_max = np.log(df_movies[df_movies["gender"]=="male"]["budget_adj"]).max()
male_coeff = model_2_gross_fit.params["gender[T.male]"]
male_budget_coeff = model_2_gross_fit.params["gender[T.male]:np.log(budget_adj)"]

print("\nMaximum value of budget for male movies is {:} millions".format(round(exp(male_ln_budget_adj_max), 2)))
print("At maximum budget, male will generate {:.2%} more revenue than female".format(exp(male_coeff + (male_ln_budget_adj_max * male_budget_coeff))-1))
print("Male will generate more revenue than female when the budget is {:} millions or higher".format(round(exp(-male_coeff/male_budget_coeff), 2)))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(gross_adj)   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.443
# Method:                 Least Squares   F-statistic:                     281.8
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):               0.00
# Time:                        23:16:06   Log-Likelihood:                -4979.8
# No. Observations:                3891   AIC:                             9984.
# Df Residuals:                    3879   BIC:                         1.006e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.4576      0.161      2.845      0.004       0.142       0.773
# gender[T.male]                       -0.5145      0.129     -3.989      0.000      -0.767      -0.262
# rating_adj[T.PG-13]                  -0.1725      0.042     -4.100      0.000      -0.255      -0.090
# rating_adj[T.R, NC-17 and others]    -0.4562      0.041    -11.002      0.000      -0.537      -0.375
# genre_adj[T.Adventure]               -0.1941      0.065     -2.965      0.003      -0.322      -0.066
# genre_adj[T.Comedy]                  -0.1837      0.040     -4.575      0.000      -0.262      -0.105
# genre_adj[T.Drama]                   -0.3551      0.048     -7.404      0.000      -0.449      -0.261
# genre_adj[T.Others]                  -0.1342      0.042     -3.221      0.001      -0.216      -0.053
# np.log(budget_adj)                    0.5196      0.032     16.410      0.000       0.458       0.582
# gender[T.male]:np.log(budget_adj)     0.1117      0.035      3.159      0.002       0.042       0.181
# year                                  0.0154      0.001     10.636      0.000       0.013       0.018
# score                                 0.3456      0.016     22.195      0.000       0.315       0.376
# ==============================================================================
# Omnibus:                       28.566   Durbin-Watson:                   1.680
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.993
# Skew:                           0.120   Prob(JB):                     1.53e-08
# Kurtosis:                       3.405   Cond. No.                         370.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Maximum value of budget for male movies is 378.45 millions
# At maximum budget, male will generate 16.04% more revenue than female
# Male will generate more revenue than female when the budget is 99.97 millions or higher

# %% [markdown]
# ### Add Gender * genre

# %%
# Add Gender * genre
model_4_gross = sm.OLS.from_formula('np.log(gross_adj) ~ gender + np.log(budget_adj) + year + score + rating_adj + genre_adj*gender', df_movies)
print(model_4_gross.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(gross_adj)   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     220.3
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):               0.00
# Time:                        23:16:06   Log-Likelihood:                -4983.5
# No. Observations:                3891   AIC:                             9997.
# Df Residuals:                    3876   BIC:                         1.009e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.1404      0.149      0.945      0.345      -0.151       0.432
# gender[T.male]                           -0.1115      0.084     -1.326      0.185      -0.276       0.053
# rating_adj[T.PG-13]                      -0.1738      0.042     -4.122      0.000      -0.256      -0.091
# rating_adj[T.R, NC-17 and others]        -0.4611      0.042    -11.103      0.000      -0.542      -0.380
# genre_adj[T.Adventure]                   -0.1602      0.166     -0.963      0.336      -0.487       0.166
# genre_adj[T.Comedy]                      -0.1989      0.096     -2.065      0.039      -0.388      -0.010
# genre_adj[T.Drama]                       -0.3951      0.105     -3.760      0.000      -0.601      -0.189
# genre_adj[T.Others]                      -0.0558      0.101     -0.550      0.582      -0.255       0.143
# genre_adj[T.Adventure]:gender[T.male]    -0.0471      0.179     -0.263      0.793      -0.398       0.304
# genre_adj[T.Comedy]:gender[T.male]        0.0162      0.104      0.157      0.875      -0.187       0.219
# genre_adj[T.Drama]:gender[T.male]         0.0565      0.116      0.487      0.626      -0.171       0.284
# genre_adj[T.Others]:gender[T.male]       -0.0998      0.109     -0.916      0.360      -0.313       0.114
# np.log(budget_adj)                        0.6066      0.016     37.067      0.000       0.575       0.639
# year                                      0.0157      0.001     10.827      0.000       0.013       0.019
# score                                     0.3465      0.016     22.210      0.000       0.316       0.377
# ==============================================================================
# Omnibus:                       51.125   Durbin-Watson:                   1.677
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.061
# Skew:                           0.144   Prob(JB):                     5.02e-17
# Kurtosis:                       3.616   Cond. No.                         563.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Add Gender * year

# %%
# Add Gender * year
model_gender_interaction = sm.OLS.from_formula('np.log(gross_adj) ~ gender + np.log(budget_adj) + year + score + rating_adj + genre_adj + gender*year', df_movies)
print(model_gender_interaction.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(gross_adj)   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     280.5
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):               0.00
# Time:                        23:16:06   Log-Likelihood:                -4983.6
# No. Observations:                3891   AIC:                             9991.
# Df Residuals:                    3879   BIC:                         1.007e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0297      0.155      0.192      0.848      -0.274       0.333
# gender[T.male]                        0.0222      0.102      0.219      0.827      -0.177       0.222
# rating_adj[T.PG-13]                  -0.1706      0.042     -4.050      0.000      -0.253      -0.088
# rating_adj[T.R, NC-17 and others]    -0.4595      0.041    -11.076      0.000      -0.541      -0.378
# genre_adj[T.Adventure]               -0.2015      0.065     -3.076      0.002      -0.330      -0.073
# genre_adj[T.Comedy]                  -0.1864      0.040     -4.636      0.000      -0.265      -0.108
# genre_adj[T.Drama]                   -0.3564      0.048     -7.422      0.000      -0.451      -0.262
# genre_adj[T.Others]                  -0.1316      0.042     -3.152      0.002      -0.213      -0.050
# np.log(budget_adj)                    0.6072      0.016     37.109      0.000       0.575       0.639
# year                                  0.0202      0.003      6.080      0.000       0.014       0.027
# gender[T.male]:year                  -0.0056      0.004     -1.524      0.128      -0.013       0.002
# score                                 0.3458      0.016     22.190      0.000       0.315       0.376
# ==============================================================================
# Omnibus:                       55.342   Durbin-Watson:                   1.679
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.947
# Skew:                           0.145   Prob(JB):                     5.90e-19
# Kurtosis:                       3.658   Cond. No.                         415.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Add Gender * score

# %%
# Add Gender * score
model_4_gross = sm.OLS.from_formula('np.log(gross_adj) ~ gender*np.log(budget_adj) + np.log(budget_adj) + year + score + rating_adj + genre_adj + score*gender', df_movies)
print(model_4_gross.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(gross_adj)   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.446
# Method:                 Least Squares   F-statistic:                     261.7
# Date:                Fri, 02 Dec 2022   Prob (F-statistic):               0.00
# Time:                        23:16:06   Log-Likelihood:                -4968.2
# No. Observations:                3891   AIC:                             9962.
# Df Residuals:                    3878   BIC:                         1.004e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             1.4271      0.258      5.536      0.000       0.922       1.933
# gender[T.male]                       -1.6958      0.278     -6.110      0.000      -2.240      -1.152
# rating_adj[T.PG-13]                  -0.1878      0.042     -4.462      0.000      -0.270      -0.105
# rating_adj[T.R, NC-17 and others]    -0.4717      0.041    -11.374      0.000      -0.553      -0.390
# genre_adj[T.Adventure]               -0.2010      0.065     -3.079      0.002      -0.329      -0.073
# genre_adj[T.Comedy]                  -0.1883      0.040     -4.701      0.000      -0.267      -0.110
# genre_adj[T.Drama]                   -0.3555      0.048     -7.434      0.000      -0.449      -0.262
# genre_adj[T.Others]                  -0.1427      0.042     -3.431      0.001      -0.224      -0.061
# np.log(budget_adj)                    0.5140      0.032     16.266      0.000       0.452       0.576
# gender[T.male]:np.log(budget_adj)     0.1159      0.035      3.286      0.001       0.047       0.185
# year                                  0.0156      0.001     10.777      0.000       0.013       0.018
# score                                 0.1966      0.035      5.670      0.000       0.129       0.265
# score:gender[T.male]                  0.1844      0.038      4.803      0.000       0.109       0.260
# ==============================================================================
# Omnibus:                       26.605   Durbin-Watson:                   1.681
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.430
# Skew:                           0.113   Prob(JB):                     5.51e-08
# Kurtosis:                       3.394   Cond. No.                         730.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4e650921-8e2a-4c48-bd86-ee489799e499' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
